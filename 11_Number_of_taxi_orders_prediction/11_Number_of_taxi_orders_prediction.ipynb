# %% [markdown]
# # Прогноз количества заказов такси

# %% [markdown]
# **Описание проекта:** Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час.
#
# **Цель проекта:** Постройте модель для предсказания количества заказов такси.
#
# **Задача:** Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.

# %% [markdown]
# ### План проекта
#
# <br>[1. Загрузка и подготовка данных](#step1)
# <br>[1.1 Вывод к этапу 1](#step2)
# <br>[2. Анализ данных](#step3)
# <br>[2.1 Вывод к этапу 2](#step4)
# <br>[3. Обучение моделей](#step5)
# <br>[3.1 Вывод к этапу 3](#step6)
# <br>[4. Тестирование моделей](#step7)
# <br>[5.Общий вывод](#step8)

# %% [markdown]
# # 1. Загрузка и подготовка данных<a id='step1'></a>

# %%
#Прежде всего импортирую нужные на этом этапе библиотеки
import pandas as pd #Импортирую библиотеку pandas
# %matplotlib inline
import matplotlib.pyplot as plt #Импортирую библиотеку matplotlib
import seaborn as sns #Импортирую библиотеку seaborn
import numpy as np #Импортирую библиотеку высокоуровневых математических функций numpy

# %%
#Читаю файл с данными
data = pd.read_csv('/datasets/taxi.csv')
#Печатаю первые 10 строк таблицы для ознакомления с данными
display(data.head(10))
#Получаю информацию о датасете
data.info()
# Out:
#               datetime  num_orders
# 0  2018-03-01 00:00:00           9
# 1  2018-03-01 00:10:00          14
# 2  2018-03-01 00:20:00          28
# 3  2018-03-01 00:30:00          20
# 4  2018-03-01 00:40:00          32
# 5  2018-03-01 00:50:00          21
# 6  2018-03-01 01:00:00           7
# 7  2018-03-01 01:10:00           5
# 8  2018-03-01 01:20:00          17
# 9  2018-03-01 01:30:00          12
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26496 entries, 0 to 26495
# Data columns (total 2 columns):
# datetime      26496 non-null object
# num_orders    26496 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 414.1+ KB

# %%
#Заново читаю файл с данными, задав параметры index_col, parse_dates, для определения datetime в столбце
data = pd.read_csv('/datasets/taxi.csv', index_col=[0], parse_dates=[0]) 
#Сортирую датасет по индексам
data.sort_index(inplace=True)
#Провожу ресемплирование на промежуток времени 1 час
data = data.resample('1H').sum()
#Печатаю первые 10 строк таблицы для ознакомления с данными
display(data.head(10))
#Получаю информацию о датасете
data.info()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43
# 2018-03-01 05:00:00           6
# 2018-03-01 06:00:00          12
# 2018-03-01 07:00:00          15
# 2018-03-01 08:00:00          34
# 2018-03-01 09:00:00          69
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4416 entries, 2018-03-01 00:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 1 columns):
# num_orders    4416 non-null int64
# dtypes: int64(1)
# memory usage: 69.0 KB

# %% [markdown]
# ## 1.1 Вывод к этапу 1 <a id='step2'></a>

# %% [markdown]
# На первом этапе произведена загрузка данных и их подготовка для обучения моделей.
# <br>Для анализа данных и построения модели предоставлен датасет, содержащий собрала исторические данные о заказах такси в аэропортах сервиса компании «Чётенькое такси».
#
# <br>**Исходный датасет состоит из следующих столбцов:**
# <br>• datetime — дата и время заказа такси
# <br>• num_orders — количество заказов такси (целевой признак)
# <br>Количество строк в датасете 4416. Пропуски в данных отсутствуют.
#
# <br>Для подготовки данных к функции *pd.read_csv* были применены парамтры *index_col* и *parse_dates* для определения данных типа datetime и назначением этого столбца в качестве индексов. Дополнительно выполнено ресемплирование на промежуток времени 1 час.

# %% [markdown]
# # 2. Анализ данных<a id='step3'></a>

# %% [markdown]
# Перед обучением моделей проведем анализ имеющихся данных.

# %%
print(data.index.min())
print(data.index.max())
print(data.index.max() - data.index.min())
print()
print(data['num_orders'].min())
print(data['num_orders'].max())
# Out:
# 2018-03-01 00:00:00
# 2018-08-31 23:00:00
# 183 days 23:00:00
#
# 0
# 462

# %% [markdown]
# Данные собраны за 183 дня и 23 часа. Минимальное количество заказов за 1 час: 0; максимальное: 462

# %% [markdown]
# Теперь проведем анализ временного ряда.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposed = seasonal_decompose(data)

plt.figure(figsize=(18, 30))
plt.subplot(311)
decomposed.trend.plot(ax=plt.gca())
plt.title('Trend')
plt.subplot(312)
decomposed.seasonal.plot(ax=plt.gca())
plt.title('Seasonality')
plt.subplot(313)
decomposed.resid.plot(ax=plt.gca())
plt.title('Residuals')
plt.tight_layout()

# %% [markdown]
# Анализ графика всего временного ряда несколько затруднен, поскольку имеет место суточная сезонность. Хотя трнед на всем ряде явно отражает постепенное увеличение заказов "Чётенького такси", вероятно маркетинговая кампания компании удачно привлекает новых "чётеньких" клиентов.
#
# Рассмотрим графики на более коротком отрезке, длинной в 1 месяц.

# %%
data_cut = data['2018-07-01':'2018-07-08']

decomposed_cut = seasonal_decompose(data_cut)

plt.figure(figsize=(18, 30))
plt.subplot(311)
decomposed_cut.trend.plot(ax=plt.gca())
plt.title('Trend')
plt.subplot(312)
decomposed_cut.seasonal.plot(ax=plt.gca())
plt.title('Seasonality')
plt.subplot(313)
decomposed_cut.resid.plot(ax=plt.gca())
plt.title('Residuals')
plt.tight_layout()

# %% [markdown]
# Так-то лучше, теперь явно видна суточная сезонность. Ночью количество заказов стремится к нулю, в то время как вечерний час пик - момент самого сильного спроса на услуги такси.

# %%
data_plot = data.copy()
data_plot['rolling_mean'] = data_plot.rolling(30).mean()
data_plot['std'] = data_plot['num_orders'].rolling(30).std()
data_plot.plot(figsize=(18, 6))

# %%
data_shift = data - data.shift()
data_shift['mean'] = data_shift['num_orders'].rolling(30).mean()
data_shift['std'] = data_shift['num_orders'].rolling(30).std()
data_shift.plot(figsize=(18, 6))

# %% [markdown]
# ## 2.1 Вывод к этапу 2 <a id='step4'></a>

# %% [markdown]
# На этом этапе проведен анализ данных. Методом декомпозиции были выделены следующие аспекты:
# 1. За время наблюдений наметился определенный тренд на общее увеличение заказов такси в течение часа, которое скорее всего вызвано ростом компании, поскольку есть гипотеза, что бизнес, связанный с такси не имеет месячной сезонности. Но данную гипотезу можно подтвердить или опровергнуть только имея данные за несколько лет.
# 2. На графиках явно видна суточная сезонность. Ночью количество заказов стремится к нулю, в то время как вечерний час пик - момент самого сильного спроса на услуги такси.

# %% [markdown]
# # 3. Обучение моделей <a id='step5'></a>

# %% [markdown]
# Обучим четыре модели ориентируясь на метрику RMSE. В качестве моделей используем Случайный лес, Линейную регрессию, LGBMRegressor, CatBoostRegressor.

# %%
from sklearn.ensemble import RandomForestRegressor #Импортирую модель RandomForestRegressor из библиотеки sklearn
from sklearn.tree import DecisionTreeRegressor #Импортирую модель DecisionTreeRegressor из библиотеки sklearn
from sklearn.linear_model import LinearRegression #Импортирую модель LinearRegression из библиотеки sklearn
from sklearn.model_selection import cross_val_score #Импортирую функцию cross_val_score из библиотеки sklearn
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV #Импортирую функцию TimeSeriesSplit и GridSearchCV 
from sklearn.metrics import make_scorer #Импортирую функцию make_scorer из библиотеки sklearn
from sklearn.model_selection import train_test_split #Импортирую функцию train_test_split из библиотеки sklearn
from sklearn.metrics import mean_squared_error #Импортирую метрику mean_squared_error из библиотеки sklearn
import lightgbm as lgb #Импортирую Light GBM
import catboost as cb #Импортирую CatBoost

# %%
#Объявляю функцию для создания признаков, а именно день недели, час "отстающие значения" и скользящее среднее
def make_features(data, max_lag, rolling_mean_size):
    #data['year'] = data.index.year
    #data['month'] = data.index.month
    #data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    data['hour'] = data.index.hour
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)

    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()

# %%
#Применяю функцию создания признаков
make_features(data, 50, 36)

# %%
data = data.dropna() #Удаляю пропуски данных, возникшие в результате работы функции make_features()
#Разделяяю датасет на обучающую и тестовую выборки
train, test = train_test_split(data, shuffle=False, test_size=0.1)

#train = train.dropna()

#Выделяю признаки и целевой признак в выборках
features_train = train.drop(['num_orders'], axis=1)
target_train = train['num_orders']

features_test = test.drop(['num_orders'], axis=1)
target_test = test['num_orders']

# %%
#Проверяю результат сплита
print(features_train.shape)
print(features_test.shape)
print(target_train.shape)
print(target_test.shape)
# Out:
# (3929, 53)
# (437, 53)
# (3929,)
# (437,)

# %% [markdown]
# display(features_train.head(10))
# display(features_train.head(10))

# %%
#Объявляю функцию для расчета метрики RMSE
def RMSE(target, predict):
    return (mean_squared_error(target, predict))**0.5
   
#С помощию функции make_scorer создаю метрику RMSE
RMSE_score = make_scorer(RMSE, greater_is_better=False)

# %% [markdown]
# В связи с тем, что мы работаем с временным рядом, нельзя применять кросс-валидацию в привычном виде для подбора гиперпараметров моделей с помощью GridSearchCV. Поэтому применим функцию TimeSeriesSplit().

# %%
# %%time
my_cv = TimeSeriesSplit(n_splits=3).split(features_train)
#Объявляю модель
regression = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
#Обучаю модель
regression.fit(features_train, target_train)
#Определяю RMSE модели с помощью кросс-валидации
regression_cv_score = pd.Series(cross_val_score(regression,features_train,target_train,scoring=RMSE_score,cv=my_cv)).mean()*(-1)
print('Среднее качество модели линейной регрессии на кросс-валидации:', regression_cv_score)
# Out:
# Среднее качество модели линейной регрессии на кросс-валидации: 25.481865724878336
# CPU times: user 432 ms, sys: 466 ms, total: 899 ms
# Wall time: 842 ms

# %%
# %%time
my_cv = TimeSeriesSplit(n_splits=3).split(features_train)
#Объявляю модель
forest = RandomForestRegressor()
#Определяю словарь с набором параметров
forest_parametrs = { 'n_estimators': range(5, 40, 5),
                     'max_depth': range(1, 14, 2),
                     'min_samples_leaf': range(1,8),
                     'min_samples_split': range(2,8,2) }

#Применяю GridSearchCV с кросс-валидацией
forest_grid = GridSearchCV(forest, forest_parametrs, scoring=RMSE_score, cv=my_cv)
forest_grid.fit(features_train, target_train)
# Out:
# CPU times: user 27min 12s, sys: 1.67 s, total: 27min 13s
# Wall time: 27min 48s
# GridSearchCV(cv=<generator object TimeSeriesSplit.split at 0x7fe11f6bc050>,
#              error_score='raise-deprecating',
#              estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                              max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimator...', n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'max_depth': range(1, 14, 2),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 8, 2),
#                          'n_estimators': range(5, 40, 5)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(RMSE, greater_is_better=False), verbose=0)

# %%
# %%time
#Определяю оптимальные гиперпараметры и качество модели на кросс-валидации
forest_params = forest_grid.best_params_
forest_score = forest_grid.score(features_train, target_train) * (-1)
print(forest_params)
print(forest_score)
print('_______________')
# Out:
# {'max_depth': 13, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 30}
# 11.298286563113471
# _______________
# CPU times: user 26.9 ms, sys: 18 µs, total: 26.9 ms
# Wall time: 40.5 ms

# %%
# %%time
my_cv = TimeSeriesSplit(n_splits=3).split(features_train)
#Объявляю модель
lg = lgb.LGBMRegressor()
#Определяю словарь с набором параметров
lg_parametrs = {"max_depth": [15, 20, 25],
               "learning_rate" : [0.1, 0.15],
               "num_leaves": range (5, 25, 5),
               "n_estimators": range (5, 40, 5)
             }
#Применяю GridSearchCV с кросс-валидацией
lg_grid = GridSearchCV(lg, lg_parametrs, scoring=RMSE_score, cv=my_cv)
lg_grid.fit(features_train, target_train)
# Out:
# CPU times: user 3min 26s, sys: 1.81 s, total: 3min 27s
# Wall time: 3min 30s
# GridSearchCV(cv=<generator object TimeSeriesSplit.split at 0x7fe11f6bc9d0>,
#              error_score='raise-deprecating',
#              estimator=LGBMRegressor(boosting_type='gbdt', class_weight=None,
#                                      colsample_bytree=1.0,
#                                      importance_type='split', learning_rate=0.1,
#                                      max_depth=-1, min_child_samples=20,
#                                      min_child_weight=0.001, min_split_gain=0.0,
#                                      n_estimators=100, n_jobs=-1, num_leaves=31,
#                                      obje...
#                                      reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                                      subsample=1.0, subsample_for_bin=200000,
#                                      subsample_freq=0),
#              iid='warn', n_jobs=None,
#              param_grid={'learning_rate': [0.1, 0.15],
#                          'max_depth': [15, 20, 25],
#                          'n_estimators': range(5, 40, 5),
#                          'num_leaves': range(5, 25, 5)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(RMSE, greater_is_better=False), verbose=0)

# %%
# %%time
#Определяю оптимальные гиперпараметры и качество модели на кросс-валидации
lg_params = lg_grid.best_params_
lg_score = lg_grid.score(features_train, target_train) * (-1)
print(lg_params)
print(lg_score)
print('_______________')
# Out:
# {'learning_rate': 0.15, 'max_depth': 15, 'n_estimators': 35, 'num_leaves': 20}
# 16.731341360553152
# _______________
# CPU times: user 73 ms, sys: 7.98 ms, total: 81 ms
# Wall time: 86.8 ms

# %%
# %%time
import catboost as cb #Импортирую CatBoost
my_cv = TimeSeriesSplit(n_splits=3).split(features_train)
#Объявляю модель
cb = cb.CatBoostRegressor()
#Определяю словарь с набором параметров
cb_parametrs = {'learning_rate': [0.03, 0.1],
                'depth': [4, 6, 10]
               }

#cb_parametrs = {"iterations": [20],
#                "depth": range(2, 14, 2),
#                "learning_rate" : [0.01, 0.1]
#             }
#Применяю GridSearchCV с кросс-валидацией
cb_grid = GridSearchCV(cb, cb_parametrs, scoring=RMSE_score, cv=my_cv)
cb_grid.fit(features_train, target_train)
# Out:
# 0:	learn: 28.7017549	total: 49ms	remaining: 48.9s
# 1:	learn: 28.3328772	total: 51.9ms	remaining: 25.9s
# 2:	learn: 27.9752476	total: 53.5ms	remaining: 17.8s
# 3:	learn: 27.6072479	total: 55.2ms	remaining: 13.7s
# 4:	learn: 27.2733715	total: 56.8ms	remaining: 11.3s
# 5:	learn: 26.9623461	total: 58.5ms	remaining: 9.68s
# 6:	learn: 26.6706701	total: 63.5ms	remaining: 9s
# 7:	learn: 26.3731322	total: 65.5ms	remaining: 8.12s
# 8:	learn: 26.0949922	total: 67.7ms	remaining: 7.45s
# 9:	learn: 25.8525489	total: 70.2ms	remaining: 6.95s
# 10:	learn: 25.5924684	total: 72.2ms	remaining: 6.49s
# 11:	learn: 25.3202070	total: 74.6ms	remaining: 6.14s
# 12:	learn: 25.0622445	total: 76.4ms	remaining: 5.8s
# 13:	learn: 24.7903206	total: 78.8ms	remaining: 5.55s
# 14:	learn: 24.5694509	total: 81.9ms	remaining: 5.38s
# 15:	learn: 24.3613768	total: 160ms	remaining: 9.84s
# 16:	learn: 24.1512300	total: 162ms	remaining: 9.39s
# 17:	learn: 23.9444686	total: 164ms	remaining: 8.95s
# 18:	learn: 23.7553164	total: 166ms	remaining: 8.58s
# 19:	learn: 23.5789409	total: 168ms	remaining: 8.23s
# 20:	learn: 23.4130464	total: 171ms	remaining: 7.95s
# 21:	learn: 23.2475035	total: 172ms	remaining: 7.65s
# 22:	learn: 23.0815091	total: 179ms	remaining: 7.59s
# 23:	learn: 22.9208352	total: 257ms	remaining: 10.5s
# 24:	learn: 22.7610624	total: 259ms	remaining: 10.1s
# 25:	learn: 22.6086205	total: 260ms	remaining: 9.75s
# 26:	learn: 22.4344690	total: 262ms	remaining: 9.44s
# 27:	learn: 22.2685687	total: 265ms	remaining: 9.19s
# 28:	learn: 22.1297200	total: 266ms	remaining: 8.91s
# 29:	learn: 22.0114269	total: 273ms	remaining: 8.82s
# 30:	learn: 21.8802218	total: 352ms	remaining: 11s
# 31:	learn: 21.7631433	total: 354ms	remaining: 10.7s
# 32:	learn: 21.6287594	total: 355ms	remaining: 10.4s
# 33:	learn: 21.5142206	total: 356ms	remaining: 10.1s
# 34:	learn: 21.3817988	total: 358ms	remaining: 9.88s
# 35:	learn: 21.2547854	total: 360ms	remaining: 9.63s
# 36:	learn: 21.1385775	total: 361ms	remaining: 9.4s
# 37:	learn: 21.0412843	total: 363ms	remaining: 9.18s
# 38:	learn: 20.9367283	total: 369ms	remaining: 9.1s
# 39:	learn: 20.8491053	total: 448ms	remaining: 10.8s
# 40:	learn: 20.7517217	total: 450ms	remaining: 10.5s
# 41:	learn: 20.6699797	total: 453ms	remaining: 10.3s
# 42:	learn: 20.5615585	total: 455ms	remaining: 10.1s
# 43:	learn: 20.4591710	total: 456ms	remaining: 9.91s
# 44:	learn: 20.3743026	total: 458ms	remaining: 9.71s
# 45:	learn: 20.3140157	total: 464ms	remaining: 9.63s
# 46:	learn: 20.2303624	total: 545ms	remaining: 11.1s
# 47:	learn: 20.1482664	total: 547ms	remaining: 10.8s
# 48:	learn: 20.0639437	total: 549ms	remaining: 10.6s
# 49:	learn: 19.9806640	total: 550ms	remaining: 10.4s
# 50:	learn: 19.9140317	total: 551ms	remaining: 10.3s
# 51:	learn: 19.8219292	total: 553ms	remaining: 10.1s
# 52:	learn: 19.7550722	total: 554ms	remaining: 9.91s
# 53:	learn: 19.6872555	total: 561ms	remaining: 9.83s
# 54:	learn: 19.6224911	total: 642ms	remaining: 11s
# 55:	learn: 19.5594414	total: 644ms	remaining: 10.8s
# 56:	learn: 19.4997105	total: 645ms	remaining: 10.7s
# 57:	learn: 19.4433813	total: 647ms	remaining: 10.5s
# 58:	learn: 19.3765277	total: 649ms	remaining: 10.3s
# 59:	learn: 19.3055145	total: 650ms	remaining: 10.2s
# 60:	learn: 19.2530650	total: 657ms	remaining: 10.1s
# 61:	learn: 19.1809179	total: 738ms	remaining: 11.2s
# 62:	learn: 19.1222998	total: 740ms	remaining: 11s
# 63:	learn: 19.0600387	total: 742ms	remaining: 10.8s
# 64:	learn: 18.9933793	total: 743ms	remaining: 10.7s
# 65:	learn: 18.9562346	total: 744ms	remaining: 10.5s
# 66:	learn: 18.9001821	total: 746ms	remaining: 10.4s
# 67:	learn: 18.8549147	total: 748ms	remaining: 10.2s
# 68:	learn: 18.8048243	total: 756ms	remaining: 10.2s
# 69:	learn: 18.7699405	total: 834ms	remaining: 11.1s
# 70:	learn: 18.7301518	total: 836ms	remaining: 10.9s
# 71:	learn: 18.6949321	total: 838ms	remaining: 10.8s
# 72:	learn: 18.6561323	total: 839ms	remaining: 10.7s
# 73:	learn: 18.5991129	total: 841ms	remaining: 10.5s
# 74:	learn: 18.5525412	total: 842ms	remaining: 10.4s
# 75:	learn: 18.5101640	total: 844ms	remaining: 10.3s
# 76:	learn: 18.4656075	total: 931ms	remaining: 11.2s
# 77:	learn: 18.4284588	total: 933ms	remaining: 11s
# 78:	learn: 18.3940263	total: 935ms	remaining: 10.9s
# 79:	learn: 18.3558803	total: 936ms	remaining: 10.8s
# 80:	learn: 18.3194950	total: 937ms	remaining: 10.6s
# 81:	learn: 18.2818787	total: 939ms	remaining: 10.5s
# 82:	learn: 18.2396725	total: 940ms	remaining: 10.4s
# 83:	learn: 18.2012749	total: 947ms	remaining: 10.3s
# 84:	learn: 18.1663258	total: 1.03s	remaining: 11.1s
# 85:	learn: 18.1341730	total: 1.03s	remaining: 10.9s
# 86:	learn: 18.0990011	total: 1.03s	remaining: 10.8s
# 87:	learn: 18.0617542	total: 1.03s	remaining: 10.7s
# 88:	learn: 18.0195719	total: 1.03s	remaining: 10.6s
# 89:	learn: 17.9809723	total: 1.03s	remaining: 10.5s
# 90:	learn: 17.9441017	total: 1.04s	remaining: 10.4s
# 91:	learn: 17.9198873	total: 1.05s	remaining: 10.3s
# 92:	learn: 17.8828775	total: 1.12s	remaining: 11s
# 93:	learn: 17.8556273	total: 1.13s	remaining: 10.9s
# 94:	learn: 17.8203230	total: 1.13s	remaining: 10.7s
# 95:	learn: 17.7830998	total: 1.13s	remaining: 10.6s
# 96:	learn: 17.7563661	total: 1.13s	remaining: 10.5s
# 97:	learn: 17.7338135	total: 1.13s	remaining: 10.4s
# 98:	learn: 17.7265609	total: 1.13s	remaining: 10.3s
# 99:	learn: 17.7001249	total: 1.14s	remaining: 10.3s
# 100:	learn: 17.6838927	total: 1.15s	remaining: 10.2s
# 101:	learn: 17.6673220	total: 1.22s	remaining: 10.7s
# 102:	learn: 17.6336065	total: 1.22s	remaining: 10.7s
# 103:	learn: 17.5995439	total: 1.23s	remaining: 10.6s
# 104:	learn: 17.5643928	total: 1.23s	remaining: 10.5s
# 105:	learn: 17.5326781	total: 1.23s	remaining: 10.4s
# 106:	learn: 17.5212652	total: 1.23s	remaining: 10.3s
# 107:	learn: 17.4861975	total: 1.24s	remaining: 10.2s
# 108:	learn: 17.4479314	total: 1.32s	remaining: 10.8s
# 109:	learn: 17.4330675	total: 1.32s	remaining: 10.7s
# 110:	learn: 17.4039498	total: 1.32s	remaining: 10.6s
# 111:	learn: 17.3852017	total: 1.32s	remaining: 10.5s
# 112:	learn: 17.3517948	total: 1.32s	remaining: 10.4s
# 113:	learn: 17.3195050	total: 1.32s	remaining: 10.3s
# 114:	learn: 17.2947163	total: 1.33s	remaining: 10.2s
# 115:	learn: 17.2747832	total: 1.41s	remaining: 10.8s
# 116:	learn: 17.2377223	total: 1.42s	remaining: 10.7s
# 117:	learn: 17.2123014	total: 1.42s	remaining: 10.6s
# 118:	learn: 17.1950554	total: 1.42s	remaining: 10.5s
# 119:	learn: 17.1701980	total: 1.42s	remaining: 10.4s
# 120:	learn: 17.1299631	total: 1.42s	remaining: 10.3s
# 121:	learn: 17.1101681	total: 1.43s	remaining: 10.3s
# 122:	learn: 17.0786747	total: 1.43s	remaining: 10.2s
# 123:	learn: 17.0651269	total: 1.51s	remaining: 10.7s
# 124:	learn: 17.0594705	total: 1.51s	remaining: 10.6s
# 125:	learn: 17.0361997	total: 1.52s	remaining: 10.5s
# 126:	learn: 17.0298949	total: 1.52s	remaining: 10.4s
# 127:	learn: 17.0192394	total: 1.52s	remaining: 10.4s
# 128:	learn: 16.9914083	total: 1.53s	remaining: 10.3s
# 129:	learn: 16.9731087	total: 1.61s	remaining: 10.8s
# 130:	learn: 16.9334393	total: 1.61s	remaining: 10.7s
# 131:	learn: 16.9191989	total: 1.61s	remaining: 10.6s
# 132:	learn: 16.8944180	total: 1.61s	remaining: 10.5s
# 133:	learn: 16.8742511	total: 1.61s	remaining: 10.4s
# 134:	learn: 16.8453384	total: 1.61s	remaining: 10.3s
# 135:	learn: 16.8215193	total: 1.61s	remaining: 10.3s
# 136:	learn: 16.8039656	total: 1.62s	remaining: 10.2s
# 137:	learn: 16.7743744	total: 1.7s	remaining: 10.6s
# 138:	learn: 16.7535846	total: 1.7s	remaining: 10.6s
# 139:	learn: 16.7334321	total: 1.71s	remaining: 10.5s
# 140:	learn: 16.7162881	total: 1.71s	remaining: 10.4s
# 141:	learn: 16.6994680	total: 1.71s	remaining: 10.3s
# 142:	learn: 16.6692348	total: 1.71s	remaining: 10.3s
# 143:	learn: 16.6543356	total: 1.72s	remaining: 10.2s
# 144:	learn: 16.6395898	total: 1.8s	remaining: 10.6s
# 145:	learn: 16.6284326	total: 1.8s	remaining: 10.5s
# 146:	learn: 16.6086024	total: 1.8s	remaining: 10.5s
# 147:	learn: 16.5831149	total: 1.8s	remaining: 10.4s
# 148:	learn: 16.5783102	total: 1.8s	remaining: 10.3s
# 149:	learn: 16.5585799	total: 1.81s	remaining: 10.2s
# 150:	learn: 16.5398030	total: 1.81s	remaining: 10.2s
# 151:	learn: 16.5174591	total: 1.82s	remaining: 10.1s
# 152:	learn: 16.4996547	total: 1.9s	remaining: 10.5s
# 153:	learn: 16.4738383	total: 1.9s	remaining: 10.4s
# 154:	learn: 16.4706828	total: 1.9s	remaining: 10.4s
# 155:	learn: 16.4414673	total: 1.9s	remaining: 10.3s
# 156:	learn: 16.4270240	total: 1.9s	remaining: 10.2s
# 157:	learn: 16.4098135	total: 1.9s	remaining: 10.1s
# 158:	learn: 16.3890338	total: 1.91s	remaining: 10.1s
# 159:	learn: 16.3817282	total: 1.91s	remaining: 10s
# 160:	learn: 16.3674692	total: 1.91s	remaining: 9.97s
# 161:	learn: 16.3559103	total: 1.99s	remaining: 10.3s
# 162:	learn: 16.3343890	total: 1.99s	remaining: 10.2s
# 163:	learn: 16.3149293	total: 1.99s	remaining: 10.2s
# 164:	learn: 16.3026683	total: 2s	remaining: 10.1s
# 165:	learn: 16.2794729	total: 2.01s	remaining: 10.1s
# 166:	learn: 16.2584357	total: 2.01s	remaining: 10s
# 167:	learn: 16.2487890	total: 2.02s	remaining: 9.99s
# 168:	learn: 16.2178026	total: 2.09s	remaining: 10.3s
# 169:	learn: 16.1958178	total: 2.09s	remaining: 10.2s
# 170:	learn: 16.1869770	total: 2.09s	remaining: 10.1s
# 171:	learn: 16.1799909	total: 2.09s	remaining: 10.1s
# 172:	learn: 16.1623238	total: 2.09s	remaining: 10s
# 173:	learn: 16.1482133	total: 2.09s	remaining: 9.94s
# 174:	learn: 16.1399790	total: 2.1s	remaining: 9.9s
# 175:	learn: 16.1241857	total: 2.18s	remaining: 10.2s
# 176:	learn: 16.1057444	total: 2.18s	remaining: 10.2s
# 177:	learn: 16.0851809	total: 2.19s	remaining: 10.1s
# 178:	learn: 16.0725636	total: 2.19s	remaining: 10s
# 179:	learn: 16.0555556	total: 2.19s	remaining: 9.97s
# 180:	learn: 16.0371108	total: 2.19s	remaining: 9.91s
# 181:	learn: 16.0223292	total: 2.19s	remaining: 9.85s
# 182:	learn: 16.0036415	total: 2.2s	remaining: 9.82s
# 183:	learn: 15.9869961	total: 2.29s	remaining: 10.2s
# 184:	learn: 15.9686916	total: 2.29s	remaining: 10.1s
# 185:	learn: 15.9618986	total: 2.29s	remaining: 10s
# 797:	learn: 9.5234850	total: 9.98s	remaining: 2.53s
# 798:	learn: 9.5155408	total: 9.99s	remaining: 2.51s
# 799:	learn: 9.5081074	total: 9.99s	remaining: 2.5s
# 800:	learn: 9.4980573	total: 9.99s	remaining: 2.48s
# 801:	learn: 9.4925646	total: 9.99s	remaining: 2.47s
# 802:	learn: 9.4876910	total: 10s	remaining: 2.45s
# 803:	learn: 9.4803958	total: 10.1s	remaining: 2.46s
# 804:	learn: 9.4741438	total: 10.1s	remaining: 2.44s
# 805:	learn: 9.4726473	total: 10.1s	remaining: 2.42s
# 806:	learn: 9.4658137	total: 10.1s	remaining: 2.41s
# 807:	learn: 9.4578510	total: 10.1s	remaining: 2.4s
# 808:	learn: 9.4492171	total: 10.1s	remaining: 2.38s
# 809:	learn: 9.4406314	total: 10.1s	remaining: 2.36s
# 810:	learn: 9.4359505	total: 10.1s	remaining: 2.35s
# 811:	learn: 9.4266679	total: 10.2s	remaining: 2.35s
# 812:	learn: 9.4181484	total: 10.2s	remaining: 2.34s
# 813:	learn: 9.4093114	total: 10.2s	remaining: 2.32s
# 814:	learn: 9.4080480	total: 10.2s	remaining: 2.31s
# 815:	learn: 9.4065312	total: 10.2s	remaining: 2.29s
# 816:	learn: 9.4004359	total: 10.2s	remaining: 2.28s
# 817:	learn: 9.3951059	total: 10.2s	remaining: 2.27s
# 818:	learn: 9.3902611	total: 10.3s	remaining: 2.27s
# 819:	learn: 9.3834665	total: 10.3s	remaining: 2.25s
# 820:	learn: 9.3753519	total: 10.3s	remaining: 2.24s
# 821:	learn: 9.3688636	total: 10.3s	remaining: 2.22s
# 822:	learn: 9.3615720	total: 10.3s	remaining: 2.21s
# 823:	learn: 9.3531645	total: 10.3s	remaining: 2.19s
# 824:	learn: 9.3452068	total: 10.3s	remaining: 2.18s
# 825:	learn: 9.3427479	total: 10.3s	remaining: 2.16s
# 826:	learn: 9.3333028	total: 10.3s	remaining: 2.15s
# 827:	learn: 9.3298353	total: 10.4s	remaining: 2.15s
# 828:	learn: 9.3245975	total: 10.4s	remaining: 2.14s
# 829:	learn: 9.3203734	total: 10.4s	remaining: 2.12s
# 830:	learn: 9.3102207	total: 10.4s	remaining: 2.11s
# 831:	learn: 9.3046619	total: 10.4s	remaining: 2.09s
# 832:	learn: 9.2942411	total: 10.4s	remaining: 2.08s
# 833:	learn: 9.2837613	total: 10.4s	remaining: 2.06s
# 834:	learn: 9.2739098	total: 10.4s	remaining: 2.05s
# 835:	learn: 9.2727701	total: 10.5s	remaining: 2.05s
# 836:	learn: 9.2715576	total: 10.5s	remaining: 2.04s
# 837:	learn: 9.2694439	total: 10.5s	remaining: 2.02s
# 838:	learn: 9.2635890	total: 10.5s	remaining: 2.01s
# 839:	learn: 9.2559777	total: 10.5s	remaining: 1.99s
# 840:	learn: 9.2452074	total: 10.5s	remaining: 1.98s
# 841:	learn: 9.2427839	total: 10.5s	remaining: 1.97s
# 842:	learn: 9.2397231	total: 10.6s	remaining: 1.97s
# 843:	learn: 9.2329287	total: 10.6s	remaining: 1.95s
# 844:	learn: 9.2279909	total: 10.6s	remaining: 1.94s
# 845:	learn: 9.2269263	total: 10.6s	remaining: 1.92s
# 846:	learn: 9.2228984	total: 10.6s	remaining: 1.91s
# 847:	learn: 9.2153853	total: 10.6s	remaining: 1.89s
# 848:	learn: 9.2118893	total: 10.6s	remaining: 1.88s
# 849:	learn: 9.2065690	total: 10.7s	remaining: 1.88s
# 850:	learn: 9.2010410	total: 10.7s	remaining: 1.86s
# 851:	learn: 9.1932062	total: 10.7s	remaining: 1.85s
# 852:	learn: 9.1851771	total: 10.7s	remaining: 1.84s
# 853:	learn: 9.1841310	total: 10.7s	remaining: 1.82s
# 854:	learn: 9.1730589	total: 10.7s	remaining: 1.81s
# 855:	learn: 9.1716907	total: 10.7s	remaining: 1.79s
# 856:	learn: 9.1675674	total: 10.7s	remaining: 1.78s
# 857:	learn: 9.1591507	total: 10.7s	remaining: 1.78s
# 858:	learn: 9.1565006	total: 10.7s	remaining: 1.76s
# 859:	learn: 9.1491391	total: 10.8s	remaining: 1.75s
# 860:	learn: 9.1408594	total: 10.8s	remaining: 1.74s
# 861:	learn: 9.1358096	total: 10.8s	remaining: 1.72s
# 862:	learn: 9.1351057	total: 10.8s	remaining: 1.71s
# 863:	learn: 9.1272049	total: 10.8s	remaining: 1.69s
# 864:	learn: 9.1196745	total: 10.8s	remaining: 1.68s
# 865:	learn: 9.1135682	total: 10.8s	remaining: 1.68s
# 866:	learn: 9.1070868	total: 10.8s	remaining: 1.66s
# 867:	learn: 9.0980850	total: 10.8s	remaining: 1.65s
# 868:	learn: 9.0912866	total: 10.8s	remaining: 1.64s
# 869:	learn: 9.0853396	total: 10.9s	remaining: 1.62s
# 870:	learn: 9.0745427	total: 10.9s	remaining: 1.61s
# 871:	learn: 9.0735555	total: 10.9s	remaining: 1.59s
# 872:	learn: 9.0676796	total: 10.9s	remaining: 1.58s
# 873:	learn: 9.0588011	total: 10.9s	remaining: 1.58s
# 874:	learn: 9.0535653	total: 10.9s	remaining: 1.56s
# 875:	learn: 9.0505747	total: 10.9s	remaining: 1.55s
# 876:	learn: 9.0443839	total: 10.9s	remaining: 1.53s
# 877:	learn: 9.0403030	total: 10.9s	remaining: 1.52s
# 878:	learn: 9.0312888	total: 10.9s	remaining: 1.51s
# 879:	learn: 9.0302300	total: 10.9s	remaining: 1.49s
# 880:	learn: 9.0207880	total: 11s	remaining: 1.48s
# 881:	learn: 9.0138224	total: 11s	remaining: 1.47s
# 882:	learn: 9.0094600	total: 11s	remaining: 1.46s
# 883:	learn: 9.0066286	total: 11s	remaining: 1.45s
# 884:	learn: 9.0019254	total: 11s	remaining: 1.43s
# 885:	learn: 8.9941918	total: 11s	remaining: 1.42s
# 886:	learn: 8.9898106	total: 11s	remaining: 1.41s
# 887:	learn: 8.9823069	total: 11s	remaining: 1.39s
# 888:	learn: 8.9755532	total: 11s	remaining: 1.38s
# 889:	learn: 8.9705635	total: 11.1s	remaining: 1.37s
# 890:	learn: 8.9627296	total: 11.1s	remaining: 1.36s
# 891:	learn: 8.9549847	total: 11.1s	remaining: 1.35s
# 892:	learn: 8.9438304	total: 11.1s	remaining: 1.33s
# 893:	learn: 8.9364798	total: 11.1s	remaining: 1.32s
# 894:	learn: 8.9348531	total: 11.1s	remaining: 1.31s
# 895:	learn: 8.9280267	total: 11.1s	remaining: 1.29s
# 896:	learn: 8.9207273	total: 11.1s	remaining: 1.28s
# 897:	learn: 8.9135445	total: 11.2s	remaining: 1.27s
# 898:	learn: 8.9068537	total: 11.2s	remaining: 1.26s
# 899:	learn: 8.9026783	total: 11.2s	remaining: 1.25s
# 900:	learn: 8.8979433	total: 11.2s	remaining: 1.23s
# 901:	learn: 8.8911962	total: 11.2s	remaining: 1.22s
# 902:	learn: 8.8901204	total: 11.2s	remaining: 1.21s
# 903:	learn: 8.8858956	total: 11.2s	remaining: 1.19s
# 904:	learn: 8.8800589	total: 11.2s	remaining: 1.18s
# 905:	learn: 8.8772654	total: 11.3s	remaining: 1.18s
# 906:	learn: 8.8763432	total: 11.3s	remaining: 1.16s
# 907:	learn: 8.8704891	total: 11.3s	remaining: 1.15s
# 908:	learn: 8.8581091	total: 11.3s	remaining: 1.13s
# 909:	learn: 8.8513792	total: 11.3s	remaining: 1.12s
# 910:	learn: 8.8436105	total: 11.3s	remaining: 1.11s
# 911:	learn: 8.8365425	total: 11.3s	remaining: 1.09s
# 912:	learn: 8.8300834	total: 11.3s	remaining: 1.08s
# 913:	learn: 8.8242632	total: 11.4s	remaining: 1.07s
# ...
# 707:	learn: 15.1590092	total: 40.6s	remaining: 16.7s
# 708:	learn: 15.1528735	total: 40.6s	remaining: 16.7s
# 709:	learn: 15.1477160	total: 40.7s	remaining: 16.6s
# 710:	learn: 15.1394184	total: 40.8s	remaining: 16.6s
# 711:	learn: 15.1303371	total: 40.9s	remaining: 16.5s
# 712:	learn: 15.1218382	total: 40.9s	remaining: 16.5s
# 713:	learn: 15.1139524	total: 41s	remaining: 16.4s
# 714:	learn: 15.1061270	total: 41s	remaining: 16.4s
# 715:	learn: 15.0949248	total: 41.1s	remaining: 16.3s
# 716:	learn: 15.0878855	total: 41.2s	remaining: 16.2s
# 717:	learn: 15.0810606	total: 41.2s	remaining: 16.2s
# 718:	learn: 15.0740578	total: 41.2s	remaining: 16.1s
# 719:	learn: 15.0597158	total: 41.3s	remaining: 16.1s
# 720:	learn: 15.0506553	total: 41.3s	remaining: 16s
# 721:	learn: 15.0430776	total: 41.4s	remaining: 16s
# 722:	learn: 15.0367748	total: 41.4s	remaining: 15.9s
# 723:	learn: 15.0293513	total: 41.5s	remaining: 15.8s
# 724:	learn: 15.0184792	total: 41.5s	remaining: 15.8s
# 725:	learn: 15.0119107	total: 41.6s	remaining: 15.7s
# 726:	learn: 15.0048473	total: 41.7s	remaining: 15.7s
# 727:	learn: 15.0042368	total: 41.7s	remaining: 15.6s
# 728:	learn: 15.0005477	total: 41.8s	remaining: 15.5s
# 729:	learn: 14.9923899	total: 41.8s	remaining: 15.5s
# 730:	learn: 14.9861963	total: 41.9s	remaining: 15.4s
# 731:	learn: 14.9753535	total: 41.9s	remaining: 15.4s
# 732:	learn: 14.9641209	total: 42s	remaining: 15.3s
# 733:	learn: 14.9543581	total: 42.1s	remaining: 15.3s
# 734:	learn: 14.9427685	total: 42.2s	remaining: 15.2s
# 735:	learn: 14.9338915	total: 42.2s	remaining: 15.1s
# 736:	learn: 14.9272600	total: 42.3s	remaining: 15.1s
# 737:	learn: 14.9181700	total: 42.3s	remaining: 15s
# 738:	learn: 14.9106292	total: 42.4s	remaining: 15s
# 739:	learn: 14.9042349	total: 42.4s	remaining: 14.9s
# 740:	learn: 14.8963520	total: 42.5s	remaining: 14.9s
# 741:	learn: 14.8886255	total: 42.5s	remaining: 14.8s
# 742:	learn: 14.8880335	total: 42.6s	remaining: 14.7s
# 743:	learn: 14.8784938	total: 42.7s	remaining: 14.7s
# 744:	learn: 14.8674602	total: 42.7s	remaining: 14.6s
# 745:	learn: 14.8607416	total: 42.8s	remaining: 14.6s
# 746:	learn: 14.8487906	total: 42.8s	remaining: 14.5s
# 747:	learn: 14.8396916	total: 42.9s	remaining: 14.5s
# 748:	learn: 14.8342340	total: 42.9s	remaining: 14.4s
# 749:	learn: 14.8255404	total: 43s	remaining: 14.3s
# 750:	learn: 14.8169255	total: 43.1s	remaining: 14.3s
# 751:	learn: 14.8101797	total: 43.1s	remaining: 14.2s
# 752:	learn: 14.8013541	total: 43.2s	remaining: 14.2s
# 753:	learn: 14.7928479	total: 43.2s	remaining: 14.1s
# 754:	learn: 14.7804505	total: 43.3s	remaining: 14.1s
# 755:	learn: 14.7739644	total: 43.4s	remaining: 14s
# 756:	learn: 14.7678817	total: 43.4s	remaining: 13.9s
# 757:	learn: 14.7585060	total: 43.5s	remaining: 13.9s
# 758:	learn: 14.7574998	total: 43.5s	remaining: 13.8s
# 759:	learn: 14.7568372	total: 43.6s	remaining: 13.8s
# 760:	learn: 14.7467896	total: 43.6s	remaining: 13.7s
# 761:	learn: 14.7342927	total: 43.7s	remaining: 13.7s
# 762:	learn: 14.7247116	total: 43.8s	remaining: 13.6s
# 763:	learn: 14.7180587	total: 43.8s	remaining: 13.5s
# 764:	learn: 14.7152019	total: 43.8s	remaining: 13.5s
# 765:	learn: 14.7049003	total: 43.9s	remaining: 13.4s
# 766:	learn: 14.6963049	total: 44s	remaining: 13.4s
# 767:	learn: 14.6877122	total: 44s	remaining: 13.3s
# 768:	learn: 14.6745478	total: 44.1s	remaining: 13.2s
# 769:	learn: 14.6646904	total: 44.1s	remaining: 13.2s
# 770:	learn: 14.6638407	total: 44.2s	remaining: 13.1s
# 771:	learn: 14.6632845	total: 44.2s	remaining: 13.1s
# 772:	learn: 14.6539206	total: 44.3s	remaining: 13s
# 773:	learn: 14.6481008	total: 44.4s	remaining: 13s
# 774:	learn: 14.6442812	total: 44.4s	remaining: 12.9s
# 775:	learn: 14.6372888	total: 44.5s	remaining: 12.8s
# 776:	learn: 14.6278078	total: 44.5s	remaining: 12.8s
# 777:	learn: 14.6178970	total: 44.6s	remaining: 12.7s
# 778:	learn: 14.6120345	total: 44.7s	remaining: 12.7s
# 779:	learn: 14.6021925	total: 44.7s	remaining: 12.6s
# 780:	learn: 14.5950832	total: 44.8s	remaining: 12.6s
# 781:	learn: 14.5943128	total: 44.8s	remaining: 12.5s
# 782:	learn: 14.5847156	total: 44.9s	remaining: 12.4s
# 783:	learn: 14.5769274	total: 44.9s	remaining: 12.4s
# 784:	learn: 14.5683858	total: 45s	remaining: 12.3s
# 785:	learn: 14.5624270	total: 45.1s	remaining: 12.3s
# 786:	learn: 14.5572353	total: 45.1s	remaining: 12.2s
# 787:	learn: 14.5522051	total: 45.2s	remaining: 12.2s
# 788:	learn: 14.5439613	total: 45.2s	remaining: 12.1s
# 789:	learn: 14.5362173	total: 45.3s	remaining: 12s
# 790:	learn: 14.5307172	total: 45.4s	remaining: 12s
# 791:	learn: 14.5206896	total: 45.4s	remaining: 11.9s
# 792:	learn: 14.5136742	total: 45.5s	remaining: 11.9s
# 793:	learn: 14.5047184	total: 45.5s	remaining: 11.8s
# 794:	learn: 14.5041458	total: 45.6s	remaining: 11.8s
# 795:	learn: 14.4973701	total: 45.6s	remaining: 11.7s
# 796:	learn: 14.4887127	total: 45.7s	remaining: 11.6s
# 797:	learn: 14.4787491	total: 45.8s	remaining: 11.6s
# 798:	learn: 14.4689162	total: 45.8s	remaining: 11.5s
# 799:	learn: 14.4586509	total: 45.9s	remaining: 11.5s
# 800:	learn: 14.4516955	total: 45.9s	remaining: 11.4s
# 801:	learn: 14.4411132	total: 46s	remaining: 11.4s
# 802:	learn: 14.4351595	total: 46s	remaining: 11.3s
# 803:	learn: 14.4296932	total: 46.1s	remaining: 11.2s
# 804:	learn: 14.4215922	total: 46.2s	remaining: 11.2s
# 805:	learn: 14.4082839	total: 46.2s	remaining: 11.1s
# 806:	learn: 14.4006347	total: 46.3s	remaining: 11.1s
# 807:	learn: 14.3931515	total: 46.3s	remaining: 11s
# 808:	learn: 14.3833985	total: 46.4s	remaining: 11s
# 809:	learn: 14.3781328	total: 46.5s	remaining: 10.9s
# 810:	learn: 14.3732650	total: 46.5s	remaining: 10.8s
# 811:	learn: 14.3726472	total: 46.6s	remaining: 10.8s
# 812:	learn: 14.3649198	total: 46.6s	remaining: 10.7s
# 813:	learn: 14.3580890	total: 46.7s	remaining: 10.7s
# 814:	learn: 14.3461160	total: 46.8s	remaining: 10.6s
# 815:	learn: 14.3378163	total: 46.8s	remaining: 10.6s
# 816:	learn: 14.3305472	total: 46.9s	remaining: 10.5s
# 817:	learn: 14.3230595	total: 47s	remaining: 10.5s
# 818:	learn: 14.3163509	total: 47s	remaining: 10.4s
# 819:	learn: 14.3090326	total: 47.1s	remaining: 10.3s
# 820:	learn: 14.2971564	total: 47.2s	remaining: 10.3s
# 821:	learn: 14.2867899	total: 47.2s	remaining: 10.2s
# 822:	learn: 14.2817525	total: 47.3s	remaining: 10.2s
# 823:	learn: 14.2809740	total: 47.3s	remaining: 10.1s
# 824:	learn: 14.2746372	total: 47.4s	remaining: 10s
# 825:	learn: 14.2695309	total: 47.4s	remaining: 9.98s
# 826:	learn: 14.2592884	total: 47.5s	remaining: 9.93s
# 968:	learn: 13.3341184	total: 55.4s	remaining: 1.77s
# 969:	learn: 13.3282195	total: 55.4s	remaining: 1.71s
# 970:	learn: 13.3217448	total: 55.5s	remaining: 1.66s
# 971:	learn: 13.3176917	total: 55.5s	remaining: 1.6s
# 972:	learn: 13.3167269	total: 55.6s	remaining: 1.54s
# 973:	learn: 13.3102502	total: 55.7s	remaining: 1.49s
# 974:	learn: 13.3037409	total: 55.7s	remaining: 1.43s
# 975:	learn: 13.3002175	total: 55.8s	remaining: 1.37s
# 976:	learn: 13.2918699	total: 55.8s	remaining: 1.31s
# 977:	learn: 13.2843385	total: 55.9s	remaining: 1.26s
# 978:	learn: 13.2775931	total: 56s	remaining: 1.2s
# 979:	learn: 13.2697802	total: 56s	remaining: 1.14s
# 980:	learn: 13.2642806	total: 56.1s	remaining: 1.09s
# 981:	learn: 13.2589414	total: 56.1s	remaining: 1.03s
# 982:	learn: 13.2543188	total: 56.2s	remaining: 971ms
# 983:	learn: 13.2487541	total: 56.2s	remaining: 913ms
# 984:	learn: 13.2402090	total: 56.3s	remaining: 857ms
# 985:	learn: 13.2343751	total: 56.3s	remaining: 799ms
# 986:	learn: 13.2267219	total: 56.4s	remaining: 742ms
# 987:	learn: 13.2197678	total: 56.4s	remaining: 685ms
# 988:	learn: 13.2150833	total: 56.5s	remaining: 628ms
# 989:	learn: 13.2062324	total: 56.5s	remaining: 571ms
# 990:	learn: 13.2014937	total: 56.6s	remaining: 514ms
# 991:	learn: 13.1970092	total: 56.7s	remaining: 457ms
# 992:	learn: 13.1885122	total: 56.7s	remaining: 400ms
# 993:	learn: 13.1810647	total: 56.8s	remaining: 343ms
# 994:	learn: 13.1753877	total: 56.8s	remaining: 285ms
# 995:	learn: 13.1707360	total: 56.9s	remaining: 228ms
# 996:	learn: 13.1665100	total: 56.9s	remaining: 171ms
# 997:	learn: 13.1590454	total: 57s	remaining: 114ms
# 998:	learn: 13.1513316	total: 57s	remaining: 57ms
# 999:	learn: 13.1507196	total: 57.1s	remaining: 0us
# CPU times: user 25min 40s, sys: 1min 32s, total: 27min 13s
# Wall time: 28min 6s
# GridSearchCV(cv=<generator object TimeSeriesSplit.split at 0x7fe11f424050>,
#              error_score='raise-deprecating',
#              estimator=<catboost.core.CatBoostRegressor object at 0x7fe11f321450>,
#              iid='warn', n_jobs=None,
#              param_grid={'depth': [4, 6, 10], 'learning_rate': [0.03, 0.1]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(RMSE, greater_is_better=False), verbose=0)

# %%
# %%time
#Определяю оптимальные гиперпараметры и качество модели на кросс-валидации
cb_params = cb_grid.best_params_
cb_score = cb_grid.score(features_train, target_train) * (-1)
print(cb_params)
print(cb_score)
print('_______________')
# Out:
# {'depth': 6, 'learning_rate': 0.03}
# 13.150719583769032
# _______________
# CPU times: user 27.2 ms, sys: 4.56 ms, total: 31.8 ms
# Wall time: 13.9 ms

# %% [markdown]
# ## 3.1 Вывод к этапу 3 <a id='step6'></a>

# %% [markdown]
# На данном этапе подобраны гипермараметры для каждой модели.

# %% [markdown]
# # 4. Тестирование моделей <a id='step7'></a>

# %% [markdown]
# Проведем тестирование моделей с подобранными гиперпараметрами.

# %%
# %%time
#Обучаю модель
regression_model = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
regression_model.fit(features_train, target_train)
regression_model_predictions = regression_model.predict(features_test)

#Определяю метрику RMSE
regression_RMSE = round(RMSE(target_test, regression_model_predictions), 3)
print('RMSE модели Линейной регрессии:', regression_RMSE)
# Out:
# RMSE модели Линейной регрессии: 42.046
# CPU times: user 76.2 ms, sys: 59.9 ms, total: 136 ms
# Wall time: 119 ms

# %%
#Объявляю функцию для построения сравнительных графиков "целевой признак - предсказание модели"
def graphicaizer(predictions):
    model_data = pd.DataFrame({"target":target_test, "predict":predictions})
    model_data.plot(figsize=(18, 6))
    model_data['2018-08-22':'2018-08-24'].plot(figsize=(18, 6))

# %%
graphicaizer(regression_model_predictions)

# %%
# %%time
#Обучаю модель на оптимальных гиперпараметрах
forest_model = RandomForestRegressor(random_state=42,
                                     max_depth=forest_params['max_depth'],
                                     min_samples_leaf = forest_params['min_samples_leaf'],
                                     min_samples_split = forest_params['min_samples_split'],
                                     n_estimators = forest_params['n_estimators'])

forest_model.fit(features_train, target_train)
forest_model_predictions = forest_model.predict(features_test)

#Определяю метрику RMSE
forest_RMSE = round(RMSE(target_test, forest_model_predictions), 3)
print('RMSE модели Случайного леса:', forest_RMSE)
# Out:
# RMSE модели Случайного леса: 41.19
# CPU times: user 4.14 s, sys: 0 ns, total: 4.14 s
# Wall time: 4.16 s

# %%
#Объявляю функцию для построения графика важности признаков, она будет показывать только те признаки,
#важность которых больше 0.0
def feature_importance_hist(model, features_train):
    importances = list(model.feature_importances_)
    names_indices = features_train.columns
    not_null_importances = []
    not_null_indices = []

    for i in importances:
        if i>0:
            not_null_importances.append(i)
            not_null_indices.append(names_indices[importances.index(i)])
    
    plt.figure(figsize=(15, 10))
    plt.title("Feature importances")
 
    plt.bar(range(len(not_null_importances)), not_null_importances, color="g")
    plt.xticks(range(len(importances)), not_null_indices, rotation=90)
 
    plt.tight_layout()
    plt.xlim([-1, len(not_null_importances)])
    plt.show()

# %%
graphicaizer(forest_model_predictions)

# %%
#Строю график важности признаков модели
feature_importance_hist(forest_model, features_train)

# %%
# %%time
#Обучаю модель на оптимальных гиперпараметрах
lg_model = lgb.LGBMRegressor(max_depth= lg_params['max_depth'],
                             learning_rate = lg_params['learning_rate'],
                             num_leaves = lg_params['num_leaves'],
                             n_estimators = lg_params['n_estimators'])

lg_model.fit(features_train, target_train)
lg_model_predictions = lg_model.predict(features_test)

#Определяю метрику RMSE
lg_RMSE = round(RMSE(target_test, lg_model_predictions), 3)
print('RMSE модели LGBMRegressor:', lg_RMSE)
# Out:
# RMSE модели LGBMRegressor: 39.63
# CPU times: user 26.4 s, sys: 142 ms, total: 26.5 s
# Wall time: 27.1 s

# %%
graphicaizer(lg_model_predictions)

# %%
#Строю график важности признаков модели
feature_importance_hist(lg_model, features_train)

# %%
# %%time
import catboost as cb #Импортирую CatBoost (почему-то без повторного импортирования ячейка не работала)
#Обучаю модель на оптимальных гиперпараметрах

#cb_model = cb.CatBoostRegressor(iterations=cb_params['iterations'],
#                                learning_rate=cb_params['learning_rate'],
#                                depth=cb_params['depth'])


cb_model = cb.CatBoostRegressor(learning_rate=cb_params['learning_rate'],
                                depth=cb_params['depth'])

cb_model.fit(features_train, target_train, verbose=10)
cb_model_predictions = cb_model.predict(features_test)

#Определяю метрику RMSE
cb_RMSE = round(RMSE(target_test, cb_model_predictions), 3)
print('RMSE модели CatBoostRegressor:', cb_RMSE)
# Out:
# 0:	learn: 38.1194355	total: 8.93ms	remaining: 8.92s
# 10:	learn: 33.3766940	total: 599ms	remaining: 53.8s
# 20:	learn: 30.0466457	total: 1.28s	remaining: 59.8s
# 30:	learn: 27.7692394	total: 1.79s	remaining: 55.9s
# 40:	learn: 26.1857816	total: 2.28s	remaining: 53.4s
# 50:	learn: 25.0380100	total: 2.87s	remaining: 53.5s
# 60:	learn: 24.2065113	total: 3.46s	remaining: 53.3s
# 70:	learn: 23.5774875	total: 4.06s	remaining: 53.1s
# 80:	learn: 23.1009923	total: 4.56s	remaining: 51.7s
# 90:	learn: 22.7255201	total: 5.06s	remaining: 50.6s
# 100:	learn: 22.4873977	total: 5.65s	remaining: 50.3s
# 110:	learn: 22.2760365	total: 6.24s	remaining: 50s
# 120:	learn: 22.0941260	total: 6.74s	remaining: 49s
# 130:	learn: 21.8455061	total: 7.24s	remaining: 48s
# 140:	learn: 21.6919077	total: 7.82s	remaining: 47.7s
# 150:	learn: 21.5293466	total: 8.32s	remaining: 46.8s
# 160:	learn: 21.4113334	total: 8.91s	remaining: 46.5s
# 170:	learn: 21.2576676	total: 9.51s	remaining: 46.1s
# 180:	learn: 21.1716493	total: 10s	remaining: 45.2s
# 190:	learn: 21.0484797	total: 10.5s	remaining: 44.5s
# 200:	learn: 20.8847879	total: 11s	remaining: 43.7s
# 210:	learn: 20.7857741	total: 11.6s	remaining: 43.3s
# 220:	learn: 20.6371083	total: 12.2s	remaining: 42.9s
# 230:	learn: 20.5087819	total: 12.8s	remaining: 42.5s
# 240:	learn: 20.3559657	total: 13.3s	remaining: 41.8s
# 250:	learn: 20.2116421	total: 13.8s	remaining: 41.1s
# 260:	learn: 20.0380833	total: 14.4s	remaining: 40.7s
# 270:	learn: 19.8826186	total: 15s	remaining: 40.2s
# 280:	learn: 19.7268848	total: 15.5s	remaining: 39.6s
# 290:	learn: 19.5821181	total: 16.1s	remaining: 39.1s
# 300:	learn: 19.4225792	total: 16.6s	remaining: 38.7s
# 310:	learn: 19.2907225	total: 17.2s	remaining: 38.2s
# 320:	learn: 19.1519724	total: 17.8s	remaining: 37.7s
# 330:	learn: 19.0183401	total: 18.3s	remaining: 37.1s
# 340:	learn: 18.8951474	total: 18.8s	remaining: 36.4s
# 350:	learn: 18.7553154	total: 19.4s	remaining: 35.9s
# 360:	learn: 18.5935263	total: 19.9s	remaining: 35.3s
# 370:	learn: 18.4699781	total: 20.5s	remaining: 34.8s
# 380:	learn: 18.3324711	total: 21s	remaining: 34.1s
# 390:	learn: 18.2255371	total: 21.6s	remaining: 33.6s
# 400:	learn: 18.1216493	total: 22.2s	remaining: 33.1s
# 410:	learn: 18.0097190	total: 22.7s	remaining: 32.5s
# 420:	learn: 17.8757519	total: 23.3s	remaining: 32s
# 430:	learn: 17.7579825	total: 23.9s	remaining: 31.5s
# 440:	learn: 17.6441204	total: 24.4s	remaining: 30.9s
# 450:	learn: 17.5365220	total: 25s	remaining: 30.4s
# 460:	learn: 17.4304442	total: 25.6s	remaining: 29.9s
# 470:	learn: 17.3307937	total: 26.1s	remaining: 29.3s
# 480:	learn: 17.2226152	total: 26.7s	remaining: 28.8s
# 490:	learn: 17.1172229	total: 27.2s	remaining: 28.2s
# 500:	learn: 17.0332826	total: 27.8s	remaining: 27.7s
# 510:	learn: 16.9212552	total: 28.3s	remaining: 27.1s
# 520:	learn: 16.8398740	total: 28.8s	remaining: 26.5s
# 530:	learn: 16.7308753	total: 29.4s	remaining: 26s
# 540:	learn: 16.6211270	total: 30s	remaining: 25.5s
# 550:	learn: 16.5404940	total: 30.5s	remaining: 24.9s
# 560:	learn: 16.4700996	total: 31.1s	remaining: 24.3s
# 570:	learn: 16.3743982	total: 31.7s	remaining: 23.8s
# 580:	learn: 16.2755476	total: 32.3s	remaining: 23.3s
# 590:	learn: 16.1770215	total: 32.8s	remaining: 22.7s
# 600:	learn: 16.0567791	total: 33.4s	remaining: 22.2s
# 610:	learn: 15.9654390	total: 34s	remaining: 21.6s
# 620:	learn: 15.8796490	total: 34.6s	remaining: 21.1s
# 630:	learn: 15.7944445	total: 35.2s	remaining: 20.6s
# 640:	learn: 15.7042009	total: 35.7s	remaining: 20s
# 650:	learn: 15.6136769	total: 36.3s	remaining: 19.4s
# 660:	learn: 15.5189310	total: 36.9s	remaining: 18.9s
# 670:	learn: 15.4451703	total: 37.4s	remaining: 18.4s
# 680:	learn: 15.3594348	total: 38s	remaining: 17.8s
# 690:	learn: 15.2963353	total: 38.6s	remaining: 17.3s
# 700:	learn: 15.2106675	total: 39.1s	remaining: 16.7s
# 710:	learn: 15.1394184	total: 39.7s	remaining: 16.1s
# 720:	learn: 15.0506553	total: 40.3s	remaining: 15.6s
# 730:	learn: 14.9861963	total: 40.8s	remaining: 15s
# 740:	learn: 14.8963520	total: 41.4s	remaining: 14.5s
# 750:	learn: 14.8169255	total: 41.9s	remaining: 13.9s
# 760:	learn: 14.7467896	total: 42.5s	remaining: 13.3s
# 770:	learn: 14.6638407	total: 43.1s	remaining: 12.8s
# 780:	learn: 14.5950832	total: 43.7s	remaining: 12.3s
# 790:	learn: 14.5307172	total: 44.3s	remaining: 11.7s
# 800:	learn: 14.4516955	total: 44.8s	remaining: 11.1s
# 810:	learn: 14.3732650	total: 45.3s	remaining: 10.6s
# 820:	learn: 14.2971564	total: 45.9s	remaining: 10s
# 830:	learn: 14.2314917	total: 46.5s	remaining: 9.45s
# 840:	learn: 14.1646697	total: 47.1s	remaining: 8.9s
# 850:	learn: 14.0992770	total: 47.6s	remaining: 8.33s
# 860:	learn: 14.0339456	total: 48.1s	remaining: 7.77s
# 870:	learn: 13.9694139	total: 48.7s	remaining: 7.22s
# 880:	learn: 13.8977017	total: 49.3s	remaining: 6.66s
# 890:	learn: 13.8184419	total: 49.8s	remaining: 6.1s
# 900:	learn: 13.7660906	total: 50.4s	remaining: 5.54s
# 910:	learn: 13.6910486	total: 51s	remaining: 4.98s
# 920:	learn: 13.6070124	total: 51.5s	remaining: 4.42s
# 930:	learn: 13.5547511	total: 52.1s	remaining: 3.86s
# 940:	learn: 13.4942005	total: 52.6s	remaining: 3.3s
# 950:	learn: 13.4362254	total: 53.2s	remaining: 2.74s
# 960:	learn: 13.3861757	total: 53.7s	remaining: 2.18s
# 970:	learn: 13.3217448	total: 54.3s	remaining: 1.62s
# 980:	learn: 13.2642806	total: 54.9s	remaining: 1.06s
# 990:	learn: 13.2014937	total: 55.5s	remaining: 504ms
# 999:	learn: 13.1507196	total: 56s	remaining: 0us
# RMSE модели CatBoostRegressor: 39.666
# CPU times: user 50.5 s, sys: 5.69 s, total: 56.2 s
# Wall time: 58.1 s

# %%
graphicaizer(cb_model_predictions)

# %%
#Строю график важности признаков модели
feature_importance_hist(cb_model, features_train)

# %% [markdown]
# Наилучшей метрики RMSE удалось достичь при работе модели Линейной регрессии🤷🏻‍♂️. Проверм ее на адекватность.

# %%
pred_previous = target_test.shift()
pred_previous.iloc[0] = target_train.iloc[-1]

print('RMSE для проверки модели на адекватность:', round(RMSE(target_test, pred_previous), 3))
# Out:
# RMSE для проверки модели на адекватность: 59.019

# %% [markdown]
# # 5. Общий вывод<a id='step8'></a>

# %% [markdown]
# При выполнении проекта проделана следующая работа.
# <br>На первом этапе произведена загрузка данных и их подготовка для обучения моделей.
#
# <br>**Исходный датасет состоял из следующих столбцов:**
# <br>• datetime — дата и время заказа такси
# <br>• num_orders — количество заказов такси (целевой признак)
# <br>Количество строк в датасете 4416. Пропуски в данных отсутствовали.
#
# <br>Для подготовки данных к функции *pd.read_csv* были применены парамтры *index_col* и *parse_dates* для определения данных типа datetime и назначением этого столбца в качестве индексов. Дополнительно выполнено ресемплирование на промежуток времени 1 час.
#
# На втором этапе проведен анализ данных. Методом декомпозиции были выделены следующие аспекты:
# 1. За время наблюдений наметился определенный тренд на общее увеличение заказов такси в течение часа, которое скорее всего вызвано ростом компании, поскольку есть гипотеза, что бизнес, связанный с такси не имеет месячной сезонности. Но данную гипотезу можно подтвердить или опровергнуть только имея данные за несколько лет.
# 2. На графиках явно видна суточная сезонность. Ночью количество заказов стремится к нулю, в то время как вечерний час пик - момент самого сильного спроса на услуги такси.
#
# На третьем этапе к датасету были добавлены дополнительные признаки, а именно день недели, час "отстающие значения" и скользящее среднее. На дополнном датасете подобраны оптимальные гиперпараметры для моделей.
#
# На четвертом этапе проведено тестирование всех моделей, каждой из них удалось достичь требуемого показателя метрики RMSE. Анализ сравнительных графиков в двух масштабах, показал, что модели хуже всего справляются с предсказаниями на высоких пиках и на провалах, но в целом, угадывают направления движения. Наилучший показатель в данном случае у LGBMRegressor, он равен 39.63.
#
# Дополнительно хочу отметить, что неплохо было бы провести анализ вызовов такси в аэропорты, имея при этом еще и данные по прибывающим/улетающим рейсам.
